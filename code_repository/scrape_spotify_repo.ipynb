# %% [markdown]
# # **How to Extract Data using Spotify’s API, Python and Spotipy**

# %%
# !pip install request
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.19.0-py3-none-any.whl (27 kB)
# Collecting urllib3>=1.26.0
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 7.9 MB/s
# Collecting requests>=2.25.0
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spotipy) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25.0->spotipy) (2.0.12)
# Installing collected packages: urllib3, requests, spotipy
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed requests-2.27.1 spotipy-2.19.0 urllib3-1.26.9

# %%
import pandas as pd
import numpy as np

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import requests
import datetime
import base64
from urllib.parse import urlencode

# %%
# API from some people
# client_id = '234d56555aa14d96a811661dfcf00d64'
# client_secret = '0fb68f689a0c4faabbadc9f88571d739'

client_id = '5aad04a720e041a4a496cd12f71dea1b'
client_secret = '5e77400fb3f743f0a51ab6010af2b21b'

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd
import time

# %%
client_id = '5aad04a720e041a4a496cd12f71dea1b'
client_secret = '5e77400fb3f743f0a51ab6010af2b21b'

client_credentials_manager = SpotifyClientCredentials(client_id, client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
def getTrackIDs(user, playlist_id):
    ids = []
    playlist = sp.user_playlist(user, playlist_id)
    for item in playlist['tracks']['items']:
        track = item['track']
        ids.append(track['id'])
    return ids

# ids = getTrackIDs('angelicadietzel', '4R0BZVh27NUJhHGLNitU08')
ids = getTrackIDs('spotifycharts', '37i9dQZEVXbJiZcmkrIHGU')

# %%
print(len(ids))
print(ids)
# Out:
# 50
# ['1W1N3usYjgI3XGQA0iX9Vq', '0h14I7cPYi1RZG6GmVpMso', '02MWAaffLxlfxAUY7c5dvx', '1Y2zqkMEu3mJPBBMBdkIsD', '0aR0Appf7lsVGExDPnbuVT', '4fouWK6XVHhzl78KzQ1UjL', '3uUuGVFu1V7jTQL60S1r8z', '1HhNoOuqm1a5MXYEgAFl8o', '2xSIcmvFQHs2CeS34Mgp62', '5Th2Rs48Gz3iqfcGMXG5PC', '3Oww84xrmgjyr5J1ilOmAf', '1SOClUWhOi8vHZYMz3GluK', '18asYwWugKjjsihZ0YvRxO', '7EtfwHVS8FcciOBU1VnT8G', '7jtQIBanIiJOMS6RyCx6jZ', '20on25jryn53hWghthWWW3', '7rglLriMNBPAyuJOMGwi39', '3CQhud304mI5VmW6EjoTDg', '5PjdY0CKGZdEuoNab3yDmX', '2B4GHvToeLTOBB4QLzW3Ni', '50nfwKoDiSYg8zOCREWAm5', '6xIhI4a3oTB6FKkIYQWBTs', '0e8nrvls4Qqv5Rfa2UhqmO', '58HvfVOeJY7lUuCqF0m3ly', '67iP0tSPgIld3OqlzF9pec', '2xFMvrqk99biaLQavjufta', '59CfNbkERJ3NoTXDvoURjj', '6VJtTvxAxZMqS8PyA0pxCP', '5Z9KJZvQzH6PFmb8SNkxuk', '2hBkoDhuGk2AtSCprEFDFP', '0QBzMgT7NIeoCYy3sJCof1', '3eJH2nAjvNXdmPfBkALiPZ', '0RSZ8EmUPEN3ySfCgytPke', '6Q2cC3r8j2hasFAf1g00d3', '3rmo8F54jFF8OgYsqTxm5d', '6VcBDMF2ykm5HDcJMVLRZW', '5Pp64isQvPVgptiOdS9Kcn', '6fuO9uk9wbjCHvQJqk2Qpx', '2Oi1IJ6JEUX1aya9VUAA1Z', '0TBylB8tjwqp4YHSrwRJQQ', '1h3d2lvISrSIV6fS89U51S', '0GoDjVEkqdXIYrGANjTNOW', '2H7jZg2HliuQhZjfBblLrZ', '5vUnjhBzRJJIAOJPde6zDx', '2K7xn816oNHJZ0aVqdQsha', '2z12ajrQWhMwEtLgZGZSzQ', '75UUG6x5zQe0gCVOiQpa6X', '0XUIMyoe2Y9BIVLAFmFxdy', '1Al4Z4K76RCKj31mExavs7', '3uwnnTQcHM1rDqSfA4gQNz']

# %%
def getTrackFeatures(id):
  meta = sp.track(id)
  features = sp.audio_features(id)

  # meta
  name = meta['name']
  album = meta['album']['name']
  artist = meta['album']['artists'][0]['name']
  release_date = meta['album']['release_date']
  length = meta['duration_ms']
  popularity = meta['popularity']

  # features
  acousticness = features[0]['acousticness']
  danceability = features[0]['danceability']
  energy = features[0]['energy']
  instrumentalness = features[0]['instrumentalness']
  liveness = features[0]['liveness']
  loudness = features[0]['loudness']
  speechiness = features[0]['speechiness']
  tempo = features[0]['tempo']
  time_signature = features[0]['time_signature']

  track = [name, album, artist, release_date, length, popularity, danceability, acousticness, danceability, energy, instrumentalness, liveness, loudness, speechiness, tempo, time_signature]
  return track

# %%
# loop over track ids 
tracks = []
for i in range(len(ids)):
  time.sleep(.5)
  track = getTrackFeatures(ids[i])
  tracks.append(track)

# create dataset
df = pd.DataFrame(tracks, columns = ['name', 'album', 'artist', 'release_date', 'length', 'popularity', 'danceability', 'acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo', 'time_signature'])

# %%
df
# Out:
#                                                  name  \
# 0                                           Sehnsucht
# 1                                         Weg von mir
# 2                                          Heat Waves
# 3                                            Majestic
# 4                      Für den Himmel durch die Hölle
# 5                                             abcdefu
# 6                                   Where Are You Now
# 7   Enemy (with JID) - from the series Arcane Leag...
# 8                                              Remedy
# 9                                            Kopf aus
# 10                       Down Under (feat. Colin Hay)
# 11                                           Infinity
# 12                                          The Motto
# 13                              WENN DU MICH VERMISST
# 14                                       Another Love
# 15                                        Do It To It
# 16                            Cold Heart - PNAU Remix
# 17          Wie viele Lieder muss ich noch schreiben?
# 18                          STAY (with Justin Bieber)
# 19                                              Pepas
# 20                                            Shivers
# 21                                     Schmetterlinge
# 22                                  THATS WHAT I WANT
# 23                                MIDDLE OF THE NIGHT
# 24                            Ich lass dich nicht los
# 25                                            Mit Dir
# 26                                          Boyfriend
# 27                                  Ich bin unterwegs
# 28                  INDUSTRY BABY (feat. Jack Harlow)
# 29                                             Manila
# 30                         Bam Bam (feat. Ed Sheeran)
# 31                                           Acapulco
# 32                                           Auf & Ab
# 33                            Rapstars (feat. Jamule)
# 34                                         Bad Habits
# 35                                           Brooklyn
# 36                                       Sweet Dreams
# 37                    paris freestyle - skrilla remix
# 38                                       Blaues Licht
# 39                                              Späti
# 40                                 Belgisches Viertel
# 41                                          Diskothek
# 42                                     Sommergewitter
# 43                                        TO THE MOON
# 44                                           Softcore
# 45                                 Gehen oder bleiben
# 46                                        In The Dark
# 47                                             Habibi
# 48                 maybe (feat. Bring Me The Horizon)
# 49                                Cool for the Summer
#
#                                               album                artist  \
# 0                                         Sehnsucht       Miksu / Macloud
# 1                                       Weg von mir                  CIVO
# 2                        Dreamland (+ Bonus Levels)         Glass Animals
# 3                                          Majestic               Luciano
# 4                    Für den Himmel durch die Hölle              Kontra K
# 5                                           abcdefu                 GAYLE
# 6                                 Where Are You Now      Lost Frequencies
# 7                                   Mercury - Act 1       Imagine Dragons
# 8                                            Remedy                 Leony
# 9                                          Kopf aus               1986zig
# 10                     Down Under (feat. Colin Hay)                 Luude
# 11                                   Feel Something          Jaymes Young
# 12                                        The Motto                Tiësto
# 13                            WENN DU MICH VERMISST                FOURTY
# 14                                    Long Way Down             Tom Odell
# 15                                      Do It To It                ACRAZE
# 16                            The Lockdown Sessions            Elton John
# 17        Wie viele Lieder muss ich noch schreiben?                   SDP
# 18                            F*CK LOVE 3: OVER YOU         The Kid LAROI
# 19                                           La 167               Farruko
# 20                                                =            Ed Sheeran
# 21                                   Schmetterlinge                AYLIVA
# 22                                          MONTERO             Lil Nas X
# 23                              MIDDLE OF THE NIGHT            Elley Duhé
# 24                          Ich lass dich nicht los       Pietro Lombardi
# 25                                          Mit Dir                  Sido
# 26                                        Boyfriend          Dove Cameron
# 27                                Ich bin unterwegs              Morpheuz
# 28                                          MONTERO             Lil Nas X
# 29                                           Manila            Ray Dalton
# 30                       Bam Bam (feat. Ed Sheeran)        Camila Cabello
# 31                                         Acapulco          Jason Derulo
# 32                                         Auf & Ab                Montez
# 33                          Rapstars (feat. Jamule)                  MERO
# 34                                                =            Ed Sheeran
# 35                                         Brooklyn           Glockenbach
# 36                                     Sweet Dreams               Luciano
# 37                  paris freestyle (skrilla remix)              Pashanim
# 38                                    Zukunft 1 & 2            RAF Camora
# 39                                  Grosse Freiheit                  Gzuz
# 40                               Belgisches Viertel                   ART
# 41                                        Diskothek               Maxwell
# 42                                   Sommergewitter              Pashanim
# 43                                      TO THE MOON              Jnr Choi
# 44  Hard To Imagine The Neighbourhood Ever Changing     The Neighbourhood
# 45                               Gehen oder bleiben                Montez
# 46                                 Exotica (Deluxe)  Purple Disco Machine
# 47                                           Habibi                  Albi
# 48               maybe (feat. Bring Me The Horizon)     Machine Gun Kelly
# 49                                        Confident           Demi Lovato
#
#    release_date  length  popularity  danceability  acousticness  danceability  \
# 0    2022-03-04  152826          84         0.804      0.642000         0.804
# 1    2022-01-28  136666          83         0.566      0.783000         0.566
# 2    2020-08-06  238805          96         0.761      0.440000         0.761
# 3    2022-03-17  206586          70         0.582      0.012100         0.582
# 4    2022-03-17  180442          68         0.638      0.153000         0.638
# 5    2021-08-13  168601         100         0.695      0.299000         0.695
# 6    2021-07-30  148197          96         0.671      0.515000         0.671
# 7    2021-09-03  173381          88         0.728      0.237000         0.728
# 8    2022-01-14  147410          41         0.554      0.056900         0.554
# 9    2022-01-28  136120          81         0.637      0.464000         0.637
# 10   2021-11-19  158774          75         0.308      0.011600         0.308
# 11   2017-06-23  237720          96         0.671      0.148000         0.671
# 12   2021-11-04  164818          95         0.754      0.030100         0.754
# 13   2022-02-10  152582          80         0.684      0.226000         0.684
# 14   2013-06-17  244360          58         0.442      0.717000         0.442
# 15   2021-08-20  157890          95         0.854      0.020900         0.854
# 16   2021-10-22  202735          78         0.795      0.035400         0.795
# 21   0.531          0.000000    0.1030    -7.938       0.0504   82.773
# 22   0.846          0.000000    0.0486    -4.510       0.2200   87.981
# 23   0.611          0.000000    0.1160    -8.271       0.0467  185.727
# 24   0.473          0.000061    0.0914    -9.640       0.1320   96.945
# 25   0.446          0.000119    0.1190    -7.556       0.2460  114.030
# 26   0.612          0.000000    0.1940    -6.543       0.0608  179.773
# 27   0.624          0.000000    0.1320    -6.967       0.2840   92.145
# 28   0.691          0.000000    0.0476    -7.395       0.0672  150.087
# 29   0.735          0.000000    0.4230    -5.996       0.0617  150.091
# 30   0.697          0.000000    0.3330    -6.377       0.0401   94.996
# 31   0.792          0.000000    0.1550    -4.021       0.0523  122.062
# 32   0.425          0.000105    0.1150    -8.064       0.0809   99.034
# 33   0.585          0.001210    0.1640    -3.975       0.3450   91.033
# 34   0.893          0.000028    0.3660    -3.745       0.0347  126.011
# 35   0.757          0.000002    0.3340    -5.008       0.0459  123.991
# 36   0.385          0.000017    0.0946    -8.298       0.1500   95.994
# 37   0.506          0.093700    0.1670    -6.919       0.1280  145.041
# 38   0.828          0.006110    0.2580    -4.906       0.1080  144.953
# 39   0.659          0.003550    0.1650    -6.093       0.1860  140.064
# 40   0.445          0.002060    0.1140    -8.152       0.3810   93.581
# 41   0.682          0.000024    0.1370    -7.714       0.4430  139.659
# 42   0.531          0.000940    0.1120   -10.569       0.1010   91.996
# 43   0.650          0.007580    0.1110   -11.814       0.3460  144.047
# 44   0.568          0.000417    0.2860    -5.509       0.0300   93.986
# 45   0.684          0.000012    0.1220    -7.679       0.0997  105.049
# 46   0.763          0.000037    0.0783    -5.628       0.0464  115.936
# 47   0.756          0.000000    0.0808    -3.762       0.3540   90.737
# 48   0.922          0.000000    0.0976    -4.805       0.0616  176.105
# 49   0.610          0.000105    0.1400    -5.639       0.0382  114.060
#
#     time_signature
# 0                4
# 1                3
# 2                4
# 3                4
# 4                4
# 5                4
# 6                4
# 7                4
# 8                4
# 9                4
# 10               4
# 11               4
# 12               4
# 13               4
# 14               4
# 15               4
# 16               4
# 17               4
# 18               4
# 19               4
# 20               4
# 21               4
# 22               4
# 23               3
# 24               4
# 25               4
# 26               3
# 27               4
# 28               4
# 29               4
# 30               4
# 31               4
# 32               4
# 33               4
# 34               4
# 35               4
# 36               4
# 37               4
# 38               4
# 39               4
# 40               4
# 41               4
# 42               4
# 43               4
# 44               4
# 45               4
# 46               4
# 47               4
# 48               4
# 49               4

# %%
df.info()
# df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              50 non-null     object
#  1   album             50 non-null     object
#  2   artist            50 non-null     object
#  3   release_date      50 non-null     object
#  4   length            50 non-null     int64
#  5   popularity        50 non-null     int64
#  6   danceability      50 non-null     float64
#  7   acousticness      50 non-null     float64
#  8   danceability      50 non-null     float64
#  9   energy            50 non-null     float64
#  10  instrumentalness  50 non-null     float64
#  11  liveness          50 non-null     float64
#  12  loudness          50 non-null     float64
#  13  speechiness       50 non-null     float64
#  14  tempo             50 non-null     float64
#  15  time_signature    50 non-null     int64
# dtypes: float64(9), int64(3), object(4)
# memory usage: 6.4+ KB

# %%
# df.groupby(["popularity"], sort=False).apply(lambda x: x.sort_values(["popularity"])).reset_index(drop=True)

# %%
# # Export dataset
# df.to_csv("spotify.csv", sep = ',')
